# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows',200)
from pylab import plt, mpl
plt.style.use('seaborn-v0_8')
mpl.rcParams['font.family'] = 'serif'
import seaborn as sns

import scipy
import statsmodels.api as sm
from IPython.display import display


#-- lib classes and funcs
import cvxpy as cp
from pypfopt import expected_returns, risk_models
from pypfopt import BlackLittermanModel #- bayesian-based
from pypfopt import EfficientFrontier, EfficientCVaR, HRPOpt, CLA


# import mlfinlab
# import QuantLib as ql
# import yfinance as yf

# %%
# %%timeit -r 1 -n 1
# %run main.py
# Out:
# WITH BAYESIAN PRIOR
#
# Optimization weight Criteria is:
# sharpe
#
# Expected annual return: 10.9%
# Annual volatility: 32.8%
# Sharpe Ratio: 0.33
#
# Optimal weights: OrderedDict([('ASML', 0.1168478625916636), ('BABA', 0.1773910519829598), ('H4ZX.XETRA', 0.4), ('ISMAF', 0.2062207085267515), ('MRNA', 0.0995403768986249)])
# 3.05 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
benchs = api.retrieve_benchmarks() # benchmark indices
sns.histplot( benchs.filter(like='perc'), kde=True, bins=1000,)
plt.xlim(-0.2, 0.5)
# Out:
# (-0.2, 0.5)

# %%
from plotting import corr_heatmap

corr_heatmap(returns)

# %%
from analysis import sensibility_proof

sensibility_proof(returns, perturbation = 0.01)
# Out:
# Simulated variation in returns:
# symbol        ASML        BABA  H4ZX.XETRA       ISMAF        MRNA
# count   708.000000  708.000000  708.000000  708.000000  708.000000
# mean      0.000510    0.000050    0.000504    0.001582   -0.001097
# std       0.029911    0.036632    0.028516    0.035992    0.041768
# min      -0.148415   -0.115622   -0.112292   -0.258939   -0.212582
# 25%      -0.017162   -0.019145   -0.016641   -0.006416   -0.024516
# 50%       0.000292   -0.001561   -0.000937    0.000033   -0.003804
# 75%       0.018578    0.016140    0.017139    0.007002    0.020102
# max       0.147381    0.302327    0.192152    0.803621    0.172974
